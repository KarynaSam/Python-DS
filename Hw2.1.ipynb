# %% [markdown]
# <a href="https://colab.research.google.com/github/KarynaSam/Python-DS/blob/main/Hw2.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Прочитайте дані за допомогою методу read_html з таблиці "Коефіцієнт народжуваності в регіонах України (1950—2019)"

# %%
data_url = "https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8"
match_text = "Коефіцієнт народжуваності в регіонах України"
data = pd.read_html(data_url, match=match_text)
df = data[0]
display(df)
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.0  206.0  160.0   130    73   126    —    —
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82    —
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123    73   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51    —
# ...

# %% [markdown]
# 1) Вивести перші рядки таблиці за допомогою методу head

# %%
df.head()
# Out:
#              Регіон   1950   1960   1970  1990  2000  2012 2014 2019  \
# 0              Крим  230.0  206.0  160.0   130    73   126    —    —
# 1         Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2         Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3  Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4          Донецька  271.0  214.0  140.0   109    61    98   82    —
#
#           avg
# 0  154.166667
# 1  146.333333
# 2  181.500000
# 3  144.166667
# 4  148.833333

# %% [markdown]
# 2)Визначте кількість рядків та стовпців у датафреймі (атрибут shape)

# %%
df.shape
# Out:
# (28, 9)

# %% [markdown]
# 3)Замініть у таблиці значення "—" на значення NaN

# %%
df.replace('—', np.nan, inplace=True)
display(df)
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019  \
# 0                Крим  230.0  206.0  160.0   130    73   126  NaN  NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82  NaN
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123    73   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51  NaN
# ...

# %% [markdown]
# 4) Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
df.isnull().sum()
# Out:
# Регіон    0
# 1950      2
# 1960      1
# 1970      1
# 1990      0
# 2000      0
# 2012      0
# 2014      2
# 2019      4
# dtype: int64

# %% [markdown]
# 5)Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
df.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014       object
# 2019       object
# avg       float64
# dtype: object

# %% [markdown]
# 6)Замініть типи нечислових колонок на числові. Підказка - це колонки, де знаходився символ "—"

# %%
df['2014'] = df['2014'].fillna(0).astype('int64')
df['2019'] = df['2019'].fillna(0).astype('int64')
print(df.dtypes)
df
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014        int64
# 2019        int64
# avg       float64
# dtype: object
#                Регіон   1950   1960   1970  1990  2000  2012  2014  2019  \
# 0                Крим  230.0  206.0  160.0   130    73   126     0     0
# 1           Вінницька  224.0  192.0  142.0   124    84   112   109    76
# 2           Волинська  247.0  250.0  179.0   153   112   148   141   101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112   111    71
# 4            Донецька  271.0  214.0  140.0   109    61    98    82     0
# 5         Житомирська  261.0  223.0  159.0   129    89   122   120    79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151   146   104
# 7          Запорізька  219.0  197.0  150.0   124    71   106   106    68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124   122    88
# ...

# %% [markdown]
# 7)Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
df.isnull().sum()
# Out:
# Регіон    0
# 1950      0
# 1960      0
# 1970      0
# 1990      0
# 2000      0
# 2012      0
# 2014      0
# 2019      0
# dtype: int64

# %% [markdown]
# 8)Видаліть з таблиці дані по всій країні, останній рядок таблиці

# %%
df = df.drop(len(df)-1)
display(df)
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012  2014  2019  \
# 0                Крим  230.0  206.0  160.0   130    73   126     0     0
# 1           Вінницька  224.0  192.0  142.0   124    84   112   109    76
# 2           Волинська  247.0  250.0  179.0   153   112   148   141   101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112   111    71
# 4            Донецька  271.0  214.0  140.0   109    61    98    82     0
# 5         Житомирська  261.0  223.0  159.0   129    89   122   120    79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151   146   104
# 7          Запорізька  219.0  197.0  150.0   124    71   106   106    68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124   122    88
# 9            Київська  204.0  189.0  156.0   123    73   122   121    80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110   108    68
# 11          Луганська  262.0  235.0  144.0   116    62    96    51     0
# ...

# %% [markdown]
# 9)Замініть відсутні дані в стовпцях середніми значеннями цих стовпців (метод fillna)

# %%
df[df['2014']>df['2014'].mean()]
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012  2014  2019  \
# 1           Вінницька  224.0  192.0  142.0   124    84   112   109    76
# 2           Волинська  247.0  250.0  179.0   153   112   148   141   101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112   111    71
# 5         Житомирська  261.0  223.0  159.0   129    89   122   120    79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151   146   104
# 7          Запорізька  219.0  197.0  150.0   124    71   106   106    68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124   122    88
# 9            Київська  204.0  189.0  156.0   123    73   122   121    80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110   108    68
# 12          Львівська  234.0  240.0  171.0   140    91   119   119    87
# 13       Миколаївська  211.0  194.0  155.0   137    80   115   112    71
# 14            Одеська  241.0  192.0  148.0   126    80   127   123    88
# ...

# %% [markdown]
# 10)Отримайте список регіонів, де рівень народжуваності у 2019 році був вищим за середній по Україні

# %%
mean_2019 = df["2019"].mean()

df[df["2019"]> mean_2019]["Регіон"].tolist()
# Out:
# ['Вінницька',
#  'Волинська',
#  'Дніпропетровська',
#  'Житомирська',
#  'Закарпатська',
#  'Івано-Франківська',
#  'Київська',
#  'Львівська',
#  'Миколаївська',
#  'Одеська',
#  'Рівненська',
#  'Тернопільська',
#  'Херсонська',
#  'Хмельницька',
#  'Чернівецька',
#  'Київ']

# %% [markdown]
# 11)У якому регіоні була найвища народжуваність у 2014 році?

# %%
df.loc[df['2014'] == df['2014'].max()].iloc[:, 0]
# Out:
# 16    Рівненська
# Name: Регіон, dtype: object

# %% [markdown]
# 12)Побудуйте стовпчикову діаграму народжуваності по регіонах у 2019 році

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['Регіон'], df['2019'], color = "indigo")
plt.xlabel("Регіон", fontsize=10, color="indigo")
plt.ylabel("Рівень народжуваності", fontsize=10, color="indigo")
plt.title("Діаграма народжуваності по регіонах у 2014 році", fontsize=15, color="indigo")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Візуалізація**

# %%
import plotly.express as px

df['avg'] = df.mean(axis=1)
fig = px.line(df, 'Регіон', y="avg", title = "Середня народжуваність в регіонах, щорічно")
fig.show()
# Out:
# <ipython-input-7-958af9965539>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['avg'] = df.mean(axis=1)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

df.set_index('Регіон').T.plot(kind='line', marker='o', figsize=(15, 6))
plt.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0))
plt.title('Графік народжуваності в Україні по регіонам, 1950-2014 роки')
plt.show()

# %%
import seaborn as sns

sns.stripplot(data=df, y='Регіон', x='2000', size=8, color='pink').set(title = 'Народжуваність в 2000 році в Україні')
plt.show()
